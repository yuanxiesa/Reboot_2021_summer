# %%
import skimage.io
# import skimage.viewer
import numpy as np
import matplotlib.pyplot as plt
import skimage.transform

# %%
# take a close look at the data format of image files 
relative_file_path = 'img_processing_data/chair.jpg'

# %%
# read the file
image = skimage.io.imread(fname=relative_file_path)

# %%
image.shape # 3088 rows, 4160 columns, each data point is a triplet (3)
# Out:
# (3088, 4160, 3)

# %%
image[0,0,:] # RGB
# Out:
# array([127, 122, 100], dtype=uint8)

# %%
# get red
image[0,0,0]
# Out:
# 127

# %%
# get green
image[0,0,1]
# Out:
# 122

# %%
image[0,0,[0,1,2]]# get red and green
# Out:
# array([127, 122, 100], dtype=uint8)

# %%
image[0,0,:]# get red and green
# Out:
# array([127, 122, 100], dtype=uint8)

# %%
image
# Out:
# array([[[127, 122, 100],
#         [127, 122, 100],
#         [128, 122, 100],
#         ...,
#         [173, 173, 165],
#         [173, 174, 166],
#         [174, 175, 167]],
#
#        [[127, 122, 100],
#         [127, 122, 100],
#         [128, 122, 100],
#         ...,
#         [175, 175, 167],
#         [175, 176, 168],
#         [176, 177, 169]],
#
#        [[128, 122, 100],
#         [128, 122, 100],
#         [127, 121,  99],
#         ...,
#         [176, 176, 168],
#         [175, 176, 168],
#         [175, 176, 168]],
#
#        ...,
#
#        [[ 93,  83,  74],
#         [ 87,  77,  68],
#         [ 83,  73,  64],
#         ...,
#         [117,  67,  42],
#         [118,  68,  43],
#         [120,  68,  44]],
#
#        [[ 88,  78,  69],
#         [ 86,  76,  67],
#         [ 85,  75,  66],
#         ...,
#         [117,  67,  42],
#         [118,  68,  43],
#         [119,  67,  43]],
#
#        [[ 83,  73,  64],
#         [ 87,  77,  68],
#         [ 90,  80,  71],
# ...

# %%
plt.imshow(image) # use this one!

# %%
# resize the image
image.shape
# Out:
# (3088, 4160, 3)

# %%
image.shape[2]
# Out:
# 3

# %%
# make a new shape
new_shape = (image.shape[0]/2, image.shape[1]/2, image.shape[2])
small_image = skimage.transform.resize(image, new_shape)
# small_image = skimage.transform.resize(image=image, output_shape=new_shape)

# %%
plt.imshow(small_image)

# %%
small_image.shape
# Out:
# (1544, 2080, 3)
